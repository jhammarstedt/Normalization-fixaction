# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
local = "C://Users/johan/Documents/GitHub/kth_private/project_course/output/results/"
adult = pd.read_csv(f"{local}adult.csv")
cancer = pd.read_csv(f"{local}breastCancer.csv")
ch = pd.read_csv(f"{local}compHardware.csv")
wine = pd.read_csv(f"{local}wine.csv")
data = [cancer,adult,wine,ch]
display(cancer)
display(adult)
display(wine)
display(ch)
# Out:
#         Dataset        Norm type Metric  svm_mean   svm_var  knn_mean  \
# 0  breastCancer           minmax    ACC  0.971930  0.000043  0.961404
# 1  breastCancer           minmax    AUC  0.969122  0.000085  0.951732
# 2  breastCancer             tanh    ACC  0.966667  0.000043  0.961404
# 3  breastCancer             tanh    AUC  0.964630  0.000136  0.950981
# 4  breastCancer  variablescaling    ACC  0.966667  0.000043  0.945614
# 5  breastCancer  variablescaling    AUC  0.964630  0.000081  0.935155
# 6  breastCancer           zscore    ACC  0.966667  0.000043  0.961404
# 7  breastCancer           zscore    AUC  0.964630  0.000136  0.950981
# 8  breastCancer               Un    ACC  0.633333  0.001736  0.814035
# 9  breastCancer               Un    AUC  0.500000  0.000000  0.771148
#
#     knn_var  logreg_mean  logreg_var
# 0  0.000265     0.968421    0.000080
# 1  0.000297     0.961605    0.000248
# 2  0.000234     0.633333    0.001736
# 3  0.000365     0.500000    0.000000
# ...
